# %%
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset = pd.get_dummies (dataset,drop_first=True)

# %%
indep = dataset[['R&D Spend','Administration','Marketing Spend','State_Florida','State_New York']]
dep = dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep,dep,test_size = 0.03, random_state = 0)

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 200, random_state = 0)
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=200, random_state=0)

# %%
#o/p = 0.9817395577166453

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(random_state=0)

# %%
#o/p = 0.9852905651347011

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, max_depth = 10)
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=10, n_estimators=50)

# %%
#o/p =0.970978686782018

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 50, max_depth = 10, max_features = "sqrt")
regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=10, max_features='sqrt', n_estimators=50)

# %%
#o/p = 0.9117042007515419

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor( )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
#o/p = 0.992787174879278

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators=100, max_depth=None, max_features=1.0, bootstrap=True, criterion="squared_error")
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
#o/p = 0.9883972628296581

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features="sqrt",
#bootstrap=True, n_jobs=-1, random_state=42)
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_depth=10, max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=5, n_estimators=200, n_jobs=-1,
#                       random_state=42)

# %%
#o/p = 0.755236046947547

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, max_samples=0.8 )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(max_samples=0.8, n_estimators=50)

# %%
#o/p = 0.9987980388770105

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, verbose=1 )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    0.0s finished
# RandomForestRegressor(n_estimators=50, verbose=1)

# %%
#o/p = 0.9886895846552987

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, n_jobs=-1  )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=50, n_jobs=-1)

# %%
#o/p = 0.9923437177977145

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, ccp_alpha=0.01  )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(ccp_alpha=0.01, n_estimators=50)

# %%
#o/p = 0.9861783595651319

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, criterion="squared_error"  )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=50)

# %%
#o/p = 0.9652165074888766

# %%
#from sklearn.ensemble import RandomForestRegressor
#regressor = RandomForestRegressor(n_estimators = 50, random_state=42  )
#regressor.fit(X_train,Y_train)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor(n_estimators=50, random_state=42)

# %%
#o/p = 0.9856956812176373

# %%
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 50, random_state = 0, bootstrap=True, max_features="sqrt")
regressor.fit(X_train,Y_train)

# %%
Y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(Y_test,Y_pred)

# %%
r_score
# Out:
# 0.9856956812176373
