# %%
# !pip install xgboost

# %%
import xgboost
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import xgboost
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\User\.conda\envs\myenv\python.exe

# %%
# !{sys.executable} -m pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#     --------------------------------------- 1.0/72.0 MB 6.3 MB/s eta 0:00:12
#    - -------------------------------------- 1.8/72.0 MB 4.8 MB/s eta 0:00:15
#    - -------------------------------------- 2.6/72.0 MB 4.4 MB/s eta 0:00:16
#    -- ------------------------------------- 3.7/72.0 MB 4.3 MB/s eta 0:00:16
#    -- ------------------------------------- 4.5/72.0 MB 4.2 MB/s eta 0:00:17
#    -- ------------------------------------- 5.2/72.0 MB 4.1 MB/s eta 0:00:17
#    --- ------------------------------------ 6.0/72.0 MB 4.1 MB/s eta 0:00:17
#    --- ------------------------------------ 6.8/72.0 MB 4.1 MB/s eta 0:00:17
#    ---- ----------------------------------- 7.6/72.0 MB 4.0 MB/s eta 0:00:16
#    ---- ----------------------------------- 8.7/72.0 MB 4.0 MB/s eta 0:00:16
# ...

# %%
import xgboost

# %%
# !{sys.executable} -m pip install lightgbm
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    --------------------- ------------------ 0.8/1.5 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 4.5 MB/s  0:00:00
# ...

# %%
import lightgbm
