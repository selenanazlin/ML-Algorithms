# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies (dataset,dtype=int, drop_first=True)

# %%
indep = dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]
dep = dataset[['charges']]

# %%
indep
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep,dep,test_size = 1/3, random_state = 0)

# %%
#DEFAULT

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor()
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.677656364706567

# %%
# FRIEDMAN_MSE , BEST

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.6833280081032633

# %%
# FRIEDMAN_MSE , RANDOM

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.6828740919695602

# %%
# SQUARED_ERROR, RANDOM

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='squared_error', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.6988690691501929

# %%
#ABSOLUTE_ERROR, Best

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.6650749266821918

# %%
#ABSOLUTE_ERROR, Random

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.7440511916347233

# %%
#POISSON, best

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion='poisson', splitter='best')
regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.6914266835249563

# %%
#POISSON, random

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='poisson', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.6817991629384057

# %%
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
Y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(Y_test,Y_pred)

# %%
r_score
# Out:
# 0.6817991629384057
