# %%
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset = pd.get_dummies (dataset,drop_first=True)

# %%
indep = dataset[['R&D Spend','Administration','Marketing Spend','State_Florida','State_New York']]
dep = dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep,dep,test_size = 0.03, random_state = 0)

# %%
# DEFAULT

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor()
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9896883941984822

# %%
# FRIEDMAN_MSE , RANDOM

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='random')
regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9363329883476643

# %%
# FRIEDMAN_MSE , BEST

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9896883941984822

# %%
# SQUARED_ERROR, RANDOM

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='mse', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.5396202915789052

# %%
# GOT ERROR BECAUSE OLD VERSION DOES NOT RECOGNIZE "ABSOLUTE_ERROR" INSTED WE NEED TO USE "MAE"

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#0.985304490545041

# %%
#

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9604683169330177

# %%
# GOT ERROR BECAUSE OLD VERSION DOES NOT RECOGNIZE "POISSON"

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='poisson', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#0.9896883941984822

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='poisson', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#0.5177365765937723

# %%
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
# GOT ERROR BECAUSE OLD VERSION DOES NOT RECOGNIZE "SQUARED_ERROR" INSTED WE NEED TO USE "MSE"

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='squared_error', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
Y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(Y_test,Y_pred)

# %%
r_score
# Out:
# 0.9363329883476643
