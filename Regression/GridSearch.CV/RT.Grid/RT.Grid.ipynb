# %%
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset = pd.get_dummies (dataset,drop_first=True)

# %%
indep = dataset[['R&D Spend','Administration','Marketing Spend','State_Florida','State_New York']]
dep = dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep,dep,test_size = 0.03, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion': ['squared_error', 'absolute_error'],
    'max_features': ['sqrt', 'log2', None],
    'n_estimators': [10, 100]}

# %%
grid = GridSearchCV(
    RandomForestRegressor(),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)
# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_features': None, 'n_estimators': 100}: 0.9765370856605289

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.046475      0.016359         0.005187        0.001163
# 1        0.238561      0.006660         0.011569        0.000488
# 2        0.028922      0.001669         0.003593        0.000487
# 3        0.238960      0.003489         0.012168        0.000746
# 4        0.037698      0.011167         0.003990        0.000001
# 5        0.255117      0.006289         0.012367        0.001017
# 6        0.037901      0.011601         0.006380        0.006297
# 7        0.260701      0.015726         0.011570        0.000489
# 8        0.035704      0.006128         0.003990        0.000002
# 9        0.274065      0.014361         0.011170        0.000399
# 10       0.036702      0.003420         0.005784        0.003645
# 11       0.235968      0.012952         0.009176        0.001165
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4    squared_error               None                 10
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 10
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 10
# 9   absolute_error               log2                100
# 10  absolute_error               None                 10
# 11  absolute_error               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.906717
# 1   {'criterion': 'squared_error', 'max_features':...           0.825202
# 2   {'criterion': 'squared_error', 'max_features':...           0.701888
# 3   {'criterion': 'squared_error', 'max_features':...           0.826317
# 4   {'criterion': 'squared_error', 'max_features':...           0.974438
# 5   {'criterion': 'squared_error', 'max_features':...           0.972183
# 6   {'criterion': 'absolute_error', 'max_features'...           0.838988
# 7   {'criterion': 'absolute_error', 'max_features'...           0.829615
# 8   {'criterion': 'absolute_error', 'max_features'...           0.770772
# 9   {'criterion': 'absolute_error', 'max_features'...           0.832551
# 10  {'criterion': 'absolute_error', 'max_features'...           0.958185
# 11  {'criterion': 'absolute_error', 'max_features'...           0.965702
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.866180           0.817744           0.793953
# 1            0.910436           0.842381           0.820252
# 2            0.813375           0.802967           0.827304
# 3            0.906802           0.819272           0.823774
# 4            0.863633           0.878344           0.885652
# 5            0.853150           0.904094           0.888202
# 6            0.899187           0.840382           0.807992
# 7            0.920679           0.860197           0.815646
# 8            0.826259           0.909386           0.773279
# 9            0.920679           0.827740           0.822306
# 10           0.854638           0.871324           0.894792
# 11           0.879186           0.916806           0.887048
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.728781         0.822675        0.061026               11
# 1            0.855928         0.850840        0.032379                6
# 2            0.824873         0.794081        0.046910               12
# 3            0.826698         0.840572        0.033220                8
# 4            0.943809         0.909175        0.042513                3
# 5            0.948592         0.913244        0.042533                2
# 6            0.769304         0.831171        0.042748                9
# 7            0.838622         0.852952        0.036827                5
# 8            0.844104         0.824760        0.051192               10
# 9            0.842742         0.849204        0.036364                7
# 10           0.924672         0.900722        0.037145                4
# 11           0.962788         0.922306        0.036482                1

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:28
# BMI:56
# Children:1
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[175831.9553]
