# %%
import pickle

# %%
model = pickle.load(open("finalized_model_Forest.sav",'rb'))

# %%
age_input = float(input("Age:"))
sex_input = float(input("Sex 0 or 1:"))
bml_input = float(input("BML:"))
children_input = float(input("Children:"))
smoker_input = float(input("Smoker 0 or 1:"))
# Out:
# Age:19
# Sex 0 or 1:0
# BML:27.9
# Children:0
# Smoker 0 or 1:1

# %%
result=model.predict([[age_input,sex_input,bml_input,children_input,smoker_input]])
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([17317.85361285])

# %%
age_input = float(input("Age:"))
sex_input = float(input("Sex 0 or 1:"))
bml_input = float(input("BML:"))
children_input = float(input("Children:"))
smoker_input = float(input("Smoker 0 or 1:"))
# Out:
# Age:32
# Sex 0 or 1:1
# BML:22.798
# Children:3
# Smoker 0 or 1:0

# %%
result=model.predict([[age_input,sex_input,bml_input,children_input,smoker_input]])
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([5715.30936645])
