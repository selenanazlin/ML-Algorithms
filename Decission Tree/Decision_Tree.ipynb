# %%
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset = pd.get_dummies (dataset,drop_first=True)

# %%
indep = dataset[['R&D Spend','Administration','Marketing Spend','State_Florida','State_New York']]
dep = dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep,dep,test_size = 0.03, random_state = 0)

# %%
# DEFAULT

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor()
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9896883941984822

# %%
# FRIEDMAN_MSE , RANDOM

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = -0.5389121217125181

# %%
# FRIEDMAN_MSE , BEST

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='friedman_mse', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9896883941984822

# %%
# SQUARED_ERROR, RANDOM

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='mse', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.5396202915789052

# %%
# GOT ERROR BECAUSE OLD VERSION DOES NOT RECOGNIZE "ABSOLUTE_ERROR" INSTED WE NEED TO USE "MAE"

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='best')
#regressor = regressor.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-bd437c98c6f8> in <module>
#       1 from sklearn.tree import DecisionTreeRegressor
#       2 regressor = DecisionTreeRegressor(criterion='absolute_error', splitter='best')
# ----> 3 regressor = regressor.fit(X_train,Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1240         """
#    1241
# -> 1242         super().fit(
#    1243             X, y,
#    1244             sample_weight=sample_weight,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     334                                                          self.n_classes_)
#     335             else:
# --> 336                 criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
#     337                                                          n_samples)
#     338
#
# KeyError: 'absolute_error'

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='mae', splitter='best')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9896883941984822

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='mae', splitter='random')
#regressor = regressor.fit(X_train,Y_train)

# %%
#o/p = 0.9887115876456188

# %%
# GOT ERROR BECAUSE OLD VERSION DOES NOT RECOGNIZE "POISSON"

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(criterion='poisson', splitter='best')
regressor = regressor.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-3ebdd0e0737b> in <module>
#       1 from sklearn.tree import DecisionTreeRegressor
#       2 regressor = DecisionTreeRegressor(criterion='poisson', splitter='best')
# ----> 3 regressor = regressor.fit(X_train,Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1240         """
#    1241
# -> 1242         super().fit(
#    1243             X, y,
#    1244             sample_weight=sample_weight,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     334                                                          self.n_classes_)
#     335             else:
# --> 336                 criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
#     337                                                          n_samples)
#     338
#
# KeyError: 'poisson'

# %%
from sklearn import tree
tree.plot_tree(regressor)
plt.show()

# %%
# GOT ERROR BECAUSE OLD VERSION DOES NOT RECOGNIZE "SQUARED_ERROR" INSTED WE NEED TO USE "MSE"

# %%
#from sklearn.tree import DecisionTreeRegressor
#regressor = DecisionTreeRegressor(criterion='squared_error', splitter='random')
#regressor = regressor.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-2df120f5b2c2> in <module>
#       1 from sklearn.tree import DecisionTreeRegressor
#       2 regressor = DecisionTreeRegressor(criterion='squared_error', splitter='random')
# ----> 3 regressor = regressor.fit(X_train,Y_train)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1240         """
#    1241
# -> 1242         super().fit(
#    1243             X, y,
#    1244             sample_weight=sample_weight,
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     334                                                          self.n_classes_)
#     335             else:
# --> 336                 criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
#     337                                                          n_samples)
#     338
#
# KeyError: 'squared_error'

# %%
Y_pred = regressor.predict(X_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(Y_test,Y_pred)

# %%
r_score
# Out:
# 0.9887115876456188
