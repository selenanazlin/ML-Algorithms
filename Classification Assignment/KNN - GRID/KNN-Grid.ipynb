# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('CKD.csv')

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv','wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal','pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes','appet_yes', 'pe_yes', 'ane_yes']]
dep=dataset['classification_yes']

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'n_neighbors': [3,5,7,9],
              'weights': ['uniform','distance'],
              'metric': ['euclidean','manhattan']} 

grid = GridSearchCV(KNeighborsClassifier(), param_grid,cv=5, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
   
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    3.4s finished
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['euclidean', 'manhattan'],
#                          'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

grid_predictions = grid.predict(X_test) 
   
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)
 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'metric': 'manhattan', 'n_neighbors': 3, 'weights': 'uniform'}: 0.9701163285572423

# %%
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[51  0]
#  [ 4 78]]

# %%
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        51
#            1       1.00      0.95      0.97        82
#
#     accuracy                           0.97       133
#    macro avg       0.96      0.98      0.97       133
# weighted avg       0.97      0.97      0.97       133

# %%
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9873266379722621

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_metric  \
# 0        0.003790  1.595736e-03         0.006782    7.465569e-04    euclidean
# 1        0.002992  5.309834e-07         0.004189    3.993756e-04    euclidean
# 2        0.002793  3.991128e-04         0.006981    6.307510e-04    euclidean
# 3        0.002593  4.884224e-04         0.004189    3.988992e-04    euclidean
# 4        0.002194  3.988994e-04         0.007779    9.767272e-04    euclidean
# 5        0.002593  4.883248e-04         0.005186    1.163375e-03    euclidean
# 6        0.001995  5.135693e-07         0.008178    1.466058e-03    euclidean
# 7        0.001995  5.560829e-07         0.003790    3.991613e-04    euclidean
# 8        0.001994  3.568323e-07         0.006384    7.973914e-04    manhattan
# 9        0.002194  3.989936e-04         0.003989    5.091228e-07    manhattan
# 10       0.002194  3.991143e-04         0.006781    3.985886e-04    manhattan
# 11       0.002393  4.884222e-04         0.003990    6.303741e-04    manhattan
# 12       0.003990  1.783980e-03         0.006781    7.466336e-04    manhattan
# 13       0.002394  4.887149e-04         0.004388    7.979283e-04    manhattan
# 14       0.001995  6.289914e-07         0.006983    6.310530e-04    manhattan
# 15       0.001995  8.313940e-07         0.002992    6.306757e-04    manhattan
#
#    param_n_neighbors param_weights  \
# 0                  3       uniform
# 1                  3      distance
# 2                  5       uniform
# 3                  5      distance
# 4                  7       uniform
# 5                  7      distance
# 6                  9       uniform
# 7                  9      distance
# 8                  3       uniform
# 9                  3      distance
# 10                 5       uniform
# 11                 5      distance
# 12                 7       uniform
# 13                 7      distance
# 14                 9       uniform
# 15                 9      distance
#
#                                                params  split0_test_score  \
# 0   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.981569
# 1   {'metric': 'euclidean', 'n_neighbors': 3, 'wei...           0.981569
# 2   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.963284
# 3   {'metric': 'euclidean', 'n_neighbors': 5, 'wei...           0.963284
# 4   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.908877
# 5   {'metric': 'euclidean', 'n_neighbors': 7, 'wei...           0.908877
# 6   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.872586
# 7   {'metric': 'euclidean', 'n_neighbors': 9, 'wei...           0.890759
# 8   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.963284
# 9   {'metric': 'manhattan', 'n_neighbors': 3, 'wei...           0.963284
# 10  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.926978
# 11  {'metric': 'manhattan', 'n_neighbors': 5, 'wei...           0.926978
# 12  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.908877
# 13  {'metric': 'manhattan', 'n_neighbors': 7, 'wei...           0.908877
# 14  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...           0.908877
# 15  {'metric': 'manhattan', 'n_neighbors': 9, 'wei...           0.908877
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.981233           0.944023           0.962573
# 1            0.981233           0.944023           0.962573
# 2            0.962636           0.944023           0.962573
# 3            0.981233           0.944023           0.962573
# 4            0.944161           0.925524           0.981217
# 5            0.944161           0.925524           0.981217
# 6            0.925764           0.925524           0.981217
# 7            0.925764           0.925524           0.981217
# 8            0.981233           0.944023           0.981217
# 9            0.981233           0.944023           0.981217
# 10           0.981233           0.944023           0.981217
# 11           0.981233           0.944023           0.981217
# 12           0.944161           0.944023           0.981217
# 13           0.944161           0.944023           0.981217
# 14           0.944161           0.925524           0.981217
# 15           0.944161           0.925524           0.981217
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         0.973880        0.019051                3
# 1            1.000000         0.973880        0.019051                3
# 2            0.962573         0.959018        0.007502                8
# 3            0.962573         0.962737        0.011770                7
# 4            0.962573         0.944470        0.025706               13
# 5            0.962573         0.944470        0.025706               13
# 6            0.962573         0.933533        0.037299               16
# 7            0.962573         0.937167        0.031639               15
# 8            1.000000         0.973951        0.018941                1
# 9            1.000000         0.973951        0.018941                1
# 10           0.981217         0.962934        0.023038                5
# 11           0.981217         0.962934        0.023038                5
# 12           0.981217         0.951899        0.027173                9
# 13           0.981217         0.951899        0.027173                9
# 14           0.981217         0.948199        0.029179               11
# 15           0.981217         0.948199        0.029179               11

# %%
age_input=float(input("Age:"))
bp_input=float(input("bp:"))
al_input=float(input("al:"))
su_input=float(input("su:"))
bgr_input=float(input("bgr:"))
bu_input=float(input("bu:"))
sc_input=float(input("sc:"))
sod_input=float(input("sod:"))
pot_input=float(input("pot:"))
hrmo_input=float(input("hrmo:"))
pcv_input=float(input("pcv:"))
wc_input=float(input("wc:"))
rc_input=float(input("rc:"))
sg_b_input=float(input("sg_b yes 0 or 1:"))
sg_c_input=float(input("sg_c Yes 0 or 1:"))
sg_d_input=float(input("sg_d Yes 0 or 1:"))
sg_e_input=float(input("sg_e Yes 0 or 1:"))
rbc_normal_input=float(input("rbc Normal 0 or 1:"))
pc_normal_input=float(input("pc Normal 0 or 1:"))
pcc_present_input=float(input("pcc Present 0 or 1:"))
ba_present_input=float(input("ba Present 0 or 1:"))
htn_yes_input=float(input("htn Yes 0 or 1:"))
dm_yes_input=float(input("dm Yes 0 or 1:"))
cad_yes_input=float(input("cad Yes 0 or 1:"))
appet_yes_input=float(input("appet Yes 0 or 1:"))
pe_yes_input=float(input("pe Good 0 or 1:"))
ane_yes_input=float(input("ane Yes 0 or 1:"))
# Out:
# Age:22
# bp:60
# al:0
# su:0
# bgr:97
# bu:18
# sc:1.2
# sod:138
# pot:4.3
# hrmo:13.5
# pcv:42
# wc:7900
# rc:6.4
# sg_b yes 0 or 1:1
# sg_c Yes 0 or 1:0
# sg_d Yes 0 or 1:0
# sg_e Yes 0 or 1:0
# rbc Normal 0 or 1:1
# pc Normal 0 or 1:1
# pcc Present 0 or 1:0
# ba Present 0 or 1:0
# htn Yes 0 or 1:0
# dm Yes 0 or 1:1
# cad Yes 0 or 1:1
# appet Yes 0 or 1:1
# pe Good 0 or 1:0
# ane Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bp_input,al_input,su_input,bgr_input,bu_input,sc_input,sod_input,pot_input,hrmo_input,pcv_input,wc_input,rc_input,sg_b_input,sg_c_input,sg_d_input,sg_e_input,rbc_normal_input,pc_normal_input,pcc_present_input,ba_present_input,htn_yes_input,dm_yes_input,cad_yes_input,appet_yes_input,pe_yes_input,ane_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[1]
