# %%
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('50_Startups.csv')

# %%
dataset = pd.get_dummies (dataset,drop_first=True)

# %%
indep = dataset[['R&D Spend','Administration','Marketing Spend','State_Florida','State_New York']]
dep = dataset[['Profit']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(indep,dep,test_size = 0.03, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion': ['squared_error', 'absolute_error'],
    'max_features': ['sqrt', 'log2', None],
    'n_estimators': [10, 100]}

# %%
grid = GridSearchCV(
    RandomForestRegressor(),
    param_grid,
    refit=True,
    verbose=3,
    n_jobs=-1
)
# fitting the model for grid search
grid.fit(X_train, Y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_features': ['sqrt', 'log2', None],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test)
# print classification report
from sklearn.metrics import r2_score
r_score=r2_score(Y_test,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': None, 'n_estimators': 100}: 0.9892136703179399

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.037104      0.004607         0.004984    1.095071e-03
# 1        0.260703      0.032973         0.013763    1.933315e-03
# 2        0.033111      0.001323         0.004787    9.772145e-04
# 3        0.269279      0.017537         0.015959    6.016934e-03
# 4        0.038896      0.003569         0.005186    1.162819e-03
# 5        0.261700      0.022905         0.012566    1.017271e-03
# 6        0.030717      0.002132         0.003588    4.873953e-04
# 7        0.245543      0.004433         0.011371    7.987142e-04
# 8        0.028926      0.000895         0.003588    4.862874e-04
# 9        0.235169      0.020979         0.012566    2.148628e-03
# 10       0.029720      0.001163         0.003989    3.989506e-07
# 11       0.225793      0.009113         0.007779    1.466116e-03
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                100
# 2    squared_error               log2                 10
# 3    squared_error               log2                100
# 4    squared_error               None                 10
# 5    squared_error               None                100
# 6   absolute_error               sqrt                 10
# 7   absolute_error               sqrt                100
# 8   absolute_error               log2                 10
# 9   absolute_error               log2                100
# 10  absolute_error               None                 10
# 11  absolute_error               None                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.795752
# 1   {'criterion': 'squared_error', 'max_features':...           0.853884
# 2   {'criterion': 'squared_error', 'max_features':...           0.880222
# 3   {'criterion': 'squared_error', 'max_features':...           0.833572
# 4   {'criterion': 'squared_error', 'max_features':...           0.981406
# 5   {'criterion': 'squared_error', 'max_features':...           0.963966
# 6   {'criterion': 'absolute_error', 'max_features'...           0.483269
# 7   {'criterion': 'absolute_error', 'max_features'...           0.762311
# 8   {'criterion': 'absolute_error', 'max_features'...           0.895248
# 9   {'criterion': 'absolute_error', 'max_features'...           0.835468
# 10  {'criterion': 'absolute_error', 'max_features'...           0.973201
# 11  {'criterion': 'absolute_error', 'max_features'...           0.973942
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.856886           0.852837           0.818156
# 1            0.922901           0.871141           0.837834
# 2            0.926098           0.865659           0.836692
# 3            0.895088           0.861654           0.832633
# 4            0.834520           0.927677           0.884125
# 5            0.868653           0.919976           0.892472
# 6            0.821850           0.791851           0.785651
# 7            0.918076           0.865269           0.819517
# 8            0.886349           0.840553           0.819198
# 9            0.892878           0.848454           0.825620
# 10           0.888365           0.920439           0.854606
# 11           0.870768           0.911202           0.878875
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.890005         0.842727        0.032706               11
# 1            0.845115         0.866175        0.030464                5
# 2            0.781003         0.857935        0.048109                6
# 3            0.856891         0.855968        0.022846                7
# 4            0.956364         0.916819        0.052336                4
# 5            0.957255         0.920464        0.036645                1
# 6            0.838895         0.744303        0.131963               12
# 7            0.862963         0.845627        0.052074               10
# 8            0.800873         0.848444        0.036900                8
# 9            0.830124         0.846509        0.024415                9
# 10           0.951135         0.917549        0.042537                3
# 11           0.959325         0.918822        0.041573                2

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:4
# BMI:56
# Children:5
# Sex Male 0 or 1:1
# Smoker Yes 0 or 1:0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[190147.3242]
