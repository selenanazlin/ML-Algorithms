# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
X = dataset.iloc[:, 3:5].values

# %%
import hdbscan

# %%
#pip install hdbscan
# Out:
# Collecting hdbscan
#   Downloading hdbscan-0.8.41-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy<3,>=1.20 in c:\users\user\.conda\envs\myenv\lib\site-packages (from hdbscan) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from hdbscan) (1.16.3)
# Collecting scikit-learn>=1.6 (from hdbscan)
#   Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: joblib>=1.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from hdbscan) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from scikit-learn>=1.6->hdbscan) (3.6.0)
# Downloading hdbscan-0.8.41-cp311-cp311-win_amd64.whl (687 kB)
#    ---------------------------------------- 0.0/687.1 kB ? eta -:--:--
#    ---------------------------------------- 687.1/687.1 kB 9.0 MB/s  0:00:00
# Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 4.2 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.1 MB 4.0 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.4/8.1 MB 3.9 MB/s eta 0:00:02
#    --------------- ------------------------ 3.1/8.1 MB 3.9 MB/s eta 0:00:02
#    ------------------- -------------------- 3.9/8.1 MB 3.9 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.7/8.1 MB 3.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.1 MB 3.9 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/8.1 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.1/8.1 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 3.8 MB/s  0:00:02
# Installing collected packages: scikit-learn, hdbscan
#
#   Attempting uninstall: scikit-learn
#
#     Found existing installation: scikit-learn 1.4.0
#
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#     Uninstalling scikit-learn-1.4.0:
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.4.0
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    ---------------------------------------- 0/2 [scikit-learn]
#    -------------------- ------------------- 1/2 [hdbscan]
#    -------------------- ------------------- 1/2 [hdbscan]
#    -------------------- ------------------- 1/2 [hdbscan]
#    ---------------------------------------- 2/2 [hdbscan]
#
# Successfully installed hdbscan-0.8.41 scikit-learn-1.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
model = hdbscan.HDBSCAN(min_cluster_size=10)
cluster = model.fit_predict(X)

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
supervised['Cluster_group']=cluster

# %%
supervised
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0               -1
# 1               -1
# 2               -1
# 3               -1
# 4               -1
# ..             ...
# 195             -1
# 196             -1
# 197             -1
# 198             -1
# 199             -1
#
# [200 rows x 6 columns]

# %%
import seaborn as sns
facet = sns.lmplot(data=supervised, x=supervised.columns[3], y=supervised.columns[4], hue=supervised.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Users\User\.conda\envs\myenv\Lib\site-packages\seaborn\regression.py:598: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
#pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\user\.conda\envs\myenv\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\user\.conda\envs\myenv\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\user\.conda\envs\myenv\lib\site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\.conda\envs\myenv\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\.conda\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\.conda\envs\myenv\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\.conda\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
